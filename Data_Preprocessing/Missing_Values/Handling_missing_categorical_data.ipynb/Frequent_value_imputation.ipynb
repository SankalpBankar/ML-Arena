# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv', usecols=['Sex', 'Embarked', 'Cabin', 'Survived'])

# %%
df.head()
# Out:
#    Survived     Sex Cabin Embarked
# 0         0    male   NaN        S
# 1         1  female   C85        C
# 2         1  female   NaN        S
# 3         1  female  C123        S
# 4         0    male   NaN        S

# %%
df.isnull().mean()*100
# Out:
# Survived     0.000000
# Sex          0.000000
# Cabin       77.104377
# Embarked     0.224467
# dtype: float64

# %%
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
df['Sex'].mode()
# Out:
# 0    male
# Name: Sex, dtype: object

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df[df['Sex']=='TA']
